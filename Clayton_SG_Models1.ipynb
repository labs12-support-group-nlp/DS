# %%
import pickle
import pandas as pd
import numpy as np
pd.set_option('mode.chained_assignment',None)
#pickle.dump(sg, open('sg_post_dfv2.pkl', 'bw'))

# %%
df = pickle.load(open('sg_df.pkl', 'br'))
df.sample(5)
# Out:
#                                                 post_txt  abuse  acne  \
# 8738   [morning, could, wake, waed, close, eyes, slee...      0     0
# 28224  [hi, everyone, fiance, trying, conceive, mohs,...      0     0
# 17800                                 [tired, addiction]      0     0
# 11688  [hi, everyone, today, waed, ask, still, troubl...      0     0
# 11134  [sister, making, feel, guilty, life, senior, h...      0     0
#
#        adderall  adhd  adoption  adoption and fostering  agoraphobia  alcohol  \
# 8738          0     0         0                       0            0        0
# 28224         0     0         0                       0            0        0
# 17800         1     0         0                       0            0        0
# 11688         0     1         0                       0            0        0
# 11134         0     0         0                       0            0        0
#
#        alzheimers   ...    veterans  vicodin  video game addiction  \
# 8738            0   ...           0        0                     0
# 28224           0   ...           0        0                     0
# 17800           0   ...           0        0                     0
# 11688           0   ...           0        0                     0
# 11134           0   ...           0        0                     0
#
#        weight loss  wellbutrin  widow  widower  x  xanax  zoloft
# 8738             0           0      0        0  1      0       0
# 28224            0           0      0        0  1      0       0
# 17800            0           0      0        0  1      0       0
# 11688            0           0      0        0  1      0       0
# 11134            0           0      0        0  1      0       0
#
# [5 rows x 234 columns]
