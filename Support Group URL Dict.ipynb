# %%
import pandas as pd
import itertools

# %%
df = pd.read_csv('SupportGroupNumbers.csv', header = None)
gl = df[0].tolist()
gl = list(itertools.chain(gl))
gl
# Out:
# ['https://www.supportgroups.com/user/login?destination=group/node/102839/subscribe/og_group_ref',
#  'https://www.supportgroups.com/user/login?destination=group/node/253314/subscribe/og_group_ref',
#  'https://www.supportgroups.com/user/login?destination=group/node/253317/subscribe/og_group_ref',
#  'https://www.supportgroups.com/user/login?destination=group/node/253319/subscribe/og_group_ref',
#  'https://www.supportgroups.com/user/login?destination=group/node/29027/subscribe/og_group_ref',
#  'https://www.supportgroups.com/user/login?destination=group/node/29162/subscribe/og_group_ref',
#  'https://www.supportgroups.com/user/login?destination=group/node/29163/subscribe/og_group_ref',
#  'https://www.supportgroups.com/user/login?destination=group/node/29164/subscribe/og_group_ref',
#  'https://www.supportgroups.com/user/login?destination=group/node/29165/subscribe/og_group_ref',
#  'https://www.supportgroups.com/user/login?destination=group/node/29166/subscribe/og_group_ref',
# ...

# %%
merged = list(itertools.chain(*list2d))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-78a33f69c558> in <module>()
# ----> 1 df[1]
#
# ...
